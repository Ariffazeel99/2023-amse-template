# %%
import numpy as np
import pandas as pd
import sqlite3
import matplotlib.pyplot as plt
import plotly.express as px

# %%
# now

conn = sqlite3.connect('MunsterAutoScout24.sqlite')
Munster_df = pd.read_sql_query("SELECT * FROM Munster", conn)
AutoScout24_df = pd.read_sql_query("SELECT * FROM AutoScout24", conn)

print(Munster_df.columns)
print(Munster_df.head(5))
# Out:
# Index(['index', 'year', 'zipCode', 'registration_district',
#        'total_wheeled_vehicles', 'two-wheeled', 'three-wheeled',
#        'four-wheeled', 'female_owners', 'home_vehicles', 'emergency_vehicles',
#        'commercial_owners', 'tractor_units', 'forest_vehicles'],
#       dtype='object')
#    index  year  zipCode registration_district  total_wheeled_vehicles  \
# 0      0  2022   5512.0         BOTTROP,STADT                  6540.0
# 1      1  2022   5513.0   GELSENKIRCHEN,STADT                  9564.0
# 2      2  2022   5515.0        MUENSTER,STADT                 11038.0
# 3      3  2022   5554.0                BORKEN                 17873.0
# 4      4  2022   5558.0              COESFELD                 13223.0
#
#    two-wheeled  three-wheeled  four-wheeled  female_owners  home_vehicles  \
# 0       6398.0           65.0          77.0          850.0          785.0
# 1       9265.0          154.0         145.0         1258.0         1005.0
# 2      10802.0          136.0         100.0         1584.0         3312.0
# 3      17282.0          207.0         384.0         2475.0         4309.0
# 4      12815.0          140.0         268.0         1863.0         3204.0
#
#    emergency_vehicles  commercial_owners  tractor_units  forest_vehicles
# 0                21.0             4767.0          284.0            459.0
# 1                82.0            11100.0          652.0            418.0
# 2                77.0            25238.0          558.0           1662.0
# 3                78.0            23945.0         2568.0          10095.0
# 4                60.0            11154.0          896.0           6677.0

# %%
print(AutoScout24_df.columns)
print(AutoScout24_df.head(5))
# Out:
# Index(['index', 'mileage', 'make', 'model', 'fuel', 'gear', 'offerType',
#        'price', 'hp', 'year'],
#       dtype='object')
#    index  mileage     make        model      fuel       gear      offerType  \
# 0      0     8800    smart      forFour  Electric  Automatic  Demonstration
# 1      1    65243  Citroen  C3 Aircross  Gasoline     Manual           Used
# 2      2    30480     Opel      Mokka X  Gasoline     Manual           Used
# 3      3    39990     Ford     EcoSport  Gasoline     Manual           Used
# 4      4    21500    smart       forTwo  Electric  Automatic           Used
#
#    price   hp  year
# 0  11890   82  2018
# 1  12480  110  2018
# 2  13970  140  2018
# 3  14480  125  2018
# 4  14480   56  2018

# %%
# Select the columns of interest
columns_of_interest = ['year', 'two-wheeled', 'three-wheeled', 'four-wheeled']

# Group the dataset by Year and calculate the sum of each selected column for each year
registration_per_year = Munster_df.groupby('year')[columns_of_interest].sum()

print(registration_per_year)

# Increase the figure width
plt.figure(figsize=(12, 6))

# Extracting only the 'year' column for the x-axis
x_values = registration_per_year.index

# Plotting the car registration per year as a bar plot
plt.bar(x_values, registration_per_year['two-wheeled'], label='Two-Wheeled')
plt.bar(x_values, registration_per_year['three-wheeled'], label='Three-Wheeled')
plt.bar(x_values, registration_per_year['four-wheeled'], label='Four-Wheeled')

print(x_values)

# Set plot title and labels
plt.title('Car Registration per Year')
plt.xlabel('Year')
plt.ylabel('Number of Registrations')

# Show the legend
plt.legend()

# Display the plot
plt.show()
# Out:
# C:\Users\aries\AppData\Local\Temp\ipykernel_8384\3530787736.py:5: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   registration_per_year = Munster_df.groupby('year')[columns_of_interest].sum()
#                                               two-wheeled  three-wheeled  \
# year
# 0                                                     0.0            0.0
# 1,400 to 1,999 cm³                                    0.0            0.0
# 12,001 to 20,000 kg                                   0.0            0.0
# 2,000 and more cm³                                    0.0            0.0
# 2,801 to 3,500 kg                                     0.0            0.0
# 20,001 and more k                                     0.0            0.0
# 2018                                              14845.0          143.0
# 2019                                             130250.0         1157.0
# 2020                                             136970.0         1305.0
# 2021                                             136770.0         1366.0
# 2022                                             158798.0         1598.0
# 2023                                              21407.0          146.0
# 2024                                              13792.0           91.0
# 3,501 to 5,000 kg                                     0.0            0.0
# 5,001 to 7,500 kg                                     0.0            0.0
# 7,501 to 12,000 kg                                    0.0            0.0
# Car density per 1,000 inhabitants                     0.0            0.0
# Engine capacity up to 1,399 cm³                       0.0            0.0
# Government district                                   0.0            0.0
# Statistical code and                                  0.0            0.0
# Total                                                 0.0            0.0
# Total vehicle density per 1,000 inhabitants           0.0            0.0
# and namely with open body                             0.0            0.0
# emergency_vehicles                                    0.0            0.0
# namely commercial owners                              0.0            0.0
# namely female owners                                  0.0            0.0
# namely mobile homes                                   0.0            0.0
# of which agricultural/forestry tractors               0.0            0.0
# of which female owners                                0.0            0.0
# of which light four-wheeled motor vehicles            0.0            0.0
# of which other tractor units                          0.0            0.0
# of which three-wheeled motor vehicles                 0.0            0.0
# of which tractor units                                0.0            0.0
# of which two-wheeled motor vehicles                   0.0            0.0
# total                                                 0.0            0.0
# unknown                                               0.0            0.0
# with all-wheel drive                                  0.0            0.0
# with maximum permissible mass up to 2,800 kg          0.0            0.0
#
#                                               four-wheeled
# year
# 0                                                      0.0
# 1,400 to 1,999 cm³                                     0.0
# 12,001 to 20,000 kg                                    0.0
# 2,000 and more cm³                                     0.0
# 2,801 to 3,500 kg                                      0.0
# 20,001 and more k                                      0.0
# 2018                                                 243.0
# 2019                                                2415.0
# 2020                                                2662.0
# 2021                                                2503.0
# 2022                                                2612.0
# 2023                                                 554.0
# 2024                                                 290.0
# 3,501 to 5,000 kg                                      0.0
# 5,001 to 7,500 kg                                      0.0
# 7,501 to 12,000 kg                                     0.0
# Car density per 1,000 inhabitants                      0.0
# Engine capacity up to 1,399 cm³                        0.0
# Government district                                    0.0
# Statistical code and                                   0.0
# Total                                                  0.0
# Total vehicle density per 1,000 inhabitants            0.0
# and namely with open body                              0.0
# emergency_vehicles                                     0.0
# namely commercial owners                               0.0
# namely female owners                                   0.0
# namely mobile homes                                    0.0
# of which agricultural/forestry tractors                0.0
# of which female owners                                 0.0
# of which light four-wheeled motor vehicles             0.0
# of which other tractor units                           0.0
# of which three-wheeled motor vehicles                  0.0
# of which tractor units                                 0.0
# of which two-wheeled motor vehicles                    0.0
# total                                                  0.0
# unknown                                                0.0
# with all-wheel drive                                   0.0
# with maximum permissible mass up to 2,800 kg           0.0
# Index(['0', '1,400 to 1,999 cm³', '12,001 to 20,000 kg', '2,000 and more cm³',
#        '2,801 to 3,500 kg', '20,001 and more k', '2018', '2019', '2020',
#        '2021', '2022', '2023', '2024', '3,501 to 5,000 kg',
#        '5,001 to 7,500 kg', '7,501 to 12,000 kg',
#        'Car density per 1,000 inhabitants', 'Engine capacity up to 1,399 cm³',
#        'Government district', 'Statistical code and', 'Total',
#        'Total vehicle density per 1,000 inhabitants',
#        'and namely with open body', 'emergency_vehicles',
#        'namely commercial owners', 'namely female owners',
#        'namely mobile homes', 'of which agricultural/forestry tractors',
#        'of which female owners', 'of which light four-wheeled motor vehicles',
#        'of which other tractor units', 'of which three-wheeled motor vehicles',
#        'of which tractor units', 'of which two-wheeled motor vehicles',
#        'total', 'unknown', 'with all-wheel drive',
#        'with maximum permissible mass up to 2,800 kg'],
#       dtype='object', name='year')
